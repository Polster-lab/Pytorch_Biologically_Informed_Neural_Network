# %%
import pandas as pd

# %%
domain_data = pd.read_csv('../H3K9acDomains.csv', sep = '\t')
domain_data.head()
# Out:
#   DomainID Chr   Start     End  Width Classification  MedianCount  \
# 0    peak1   1  713361  715120   1760       Promoter           83
# 1    peak2   1  761305  763147   1843       Promoter           63
# 2    peak3   1  805156  805842    687       Enhancer           30
# 3    peak4   1  839230  840958   1729       Promoter           55
# 4    peak5   1  858838  859156    319       Promoter           18
#
#    DetectedInNumSamples
# 0                   645
# 1                   452
# 2                   363
# 3                   227
# 4                   137

# %%
domain_data.shape
# Out:
# (26384, 8)

# %%
counts_data = pd.read_csv('../ReadCounts.csv', sep = '\t')
counts_data.head()
# Out:
#        06073025  50109477  22100675  21123474  70883578  50101811  20233939  \
# peak1       101        82        88        78       118        74       102
# peak2        77        51        56        49        80        33        69
# peak3        43        29        23        35        45        21        39
# peak4        73        68        69        50        77        51        73
# peak5        17        33        24        18        24        26        17
#
#        20180815  85171938  10405008  ...  61142759  22776575  50109927  \
# peak1        72       102        85  ...        54        47        69
# peak2        49        67        72  ...        41        44        66
# peak3        28        53        31  ...        25        13        26
# peak4        55        64        65  ...        37        36        33
# peak5        22        24        29  ...        18        10        13
#
#        36492755  95491648  76867532  20613887  22868024  50500136  21293107
# peak1        57       103        51        74        39        56        62
# peak2        27        78        31        57        38        50        53
# peak3        17        30        27        22        16        27        21
# peak4        42        52        38        41        23        41        34
# peak5        13        22        15        14        14        16         6
#
# [5 rows x 669 columns]

# %%
counts_data.shape
# Out:
# (26384, 669)

# %%
meta_data = pd.read_csv('../ROSMAP_assay_ChIPseq_metadata.csv')
meta_data.head()
# Out:
#   specimenID  libraryID    assay  platform referenceSet  libraryBatch  \
# 0   R2577726        NaN  ChIPSeq       NaN       GRCh37           NaN
# 1   R8457289        NaN  ChIPSeq       NaN       GRCh37           NaN
# 2   R9217634        NaN  ChIPSeq       NaN       GRCh37           NaN
# 3   R8445323        NaN  ChIPSeq       NaN       GRCh37           NaN
# 4   R6728038        NaN  ChIPSeq       NaN       GRCh37           NaN
#
#    libraryPreparationMethod sequencingBatch assayTarget  antibody  ...  \
# 0                       NaN               8      H3K9ac       NaN  ...
# 1                       NaN               9      H3K9ac       NaN  ...
# 2                       NaN              18      H3K9ac       NaN  ...
# 3                       NaN              18      H3K9ac       NaN  ...
# 4                       NaN               4      H3K9ac       NaN  ...
#
#    MappedReads  MappedReadsPercentage  UniquelyMappedReads  \
# 0     51662021               0.921366             44617225
# 1     48633727               0.909100             41487626
# 2     53754082               0.915591             46118477
# 3     51926854               0.927358             44431183
# 4     53013377               0.943492             45665488
#
#    UniquelyMappedReadsPercentage  UniquelyMappedUniqueReads  \
# 0                       0.863637                   33374153
# 1                       0.853063                   35358556
# 2                       0.857953                   31621492
# 3                       0.855649                   32400763
# 4                       0.861396                   36281345
#
#    UniquelyMappedUniqueReadsPercentage  NonRedundantFraction  \
# 0                             0.646009              0.748011
# 1                             0.727038              0.852268
# 2                             0.588262              0.685658
# 3                             0.623969              0.729235
# 4                             0.684381              0.794503
#
#    CrossCorrelation FragmentSize    Pool
# 0          0.095119          300  4-Plex
# 1          0.067373          270  4-Plex
# 2          0.073991          280  4-Plex
# 3          0.054230          240  4-Plex
# 4          0.102771          270  4-Plex
#
# [5 rows x 30 columns]

# %%
meta_data.columns
# Out:
# Index(['specimenID', 'libraryID', 'assay', 'platform', 'referenceSet',
#        'libraryBatch', 'libraryPreparationMethod', 'sequencingBatch',
#        'assayTarget', 'antibody', 'vendor', 'catalogNumber', 'lotNumber',
#        'antibodyAmount', 'chromatinAmount', 'isStranded', 'readStrandOrigin',
#        'readLength', 'runType', 'totalReads', 'MappedReads',
#        'MappedReadsPercentage', 'UniquelyMappedReads',
#        'UniquelyMappedReadsPercentage', 'UniquelyMappedUniqueReads',
#        'UniquelyMappedUniqueReadsPercentage', 'NonRedundantFraction',
#        'CrossCorrelation', 'FragmentSize', 'Pool'],
#       dtype='object')

# %%
quality_control_data = pd.read_csv('../QualityControl.csv', sep = '\t')
quality_control_data.head()
# Out:
#    SampleID  Batch  TotalReads  MappedReads  UniquelyMappedUniqueReads  \
# 0   6073025      8    56071130     51662021                   33374153
# 1  50109477      9    53496547     48633727                   35358556
# 2  22100675     18    58709728     53754082                   31621492
# 3  21123474     18    55994398     51926854                   32400763
# 4  70883578      4    56188504     53013377                   36281345
#
#    NonRedundantFraction    GCBias  CrossCorrelation  FragmentSize  \
# 0              0.748011  1.895237          0.095119           300
# 1              0.852268  1.772193          0.067373           270
# 2              0.685658  1.775020          0.073991           280
# 3              0.729235  1.698591          0.054230           240
# 4              0.794503  2.212362          0.102771           270
#
#    NumberOfPeaks  ...  MeanPeakWidth  SdPeakWidth  FractionOfReadsInPeaks  \
# 0          23831  ...    3357.739877  3170.518889                0.179842
# 1          20644  ...    3194.660531  2909.313729                0.132553
# 2          18395  ...    3194.104267  2737.542215                0.137631
# 3          16315  ...    2988.039166  2524.648549                0.103802
# 4          26314  ...    3740.584252  3660.253624                0.203509
#
#    UniquelyMappedUniqueReadsInH3K9acDomains  CorrelationWithMedianSample  \
# 0                                   6238033                     0.991681
# 1                                   5472996                     0.986054
# 2                                   5211239                     0.986137
# 3                                   4567846                     0.989283
# 4                                   7016778                     0.986772
#
#     Neurons  Astrocytes  Oligodendrocytes  MyeloidCells  EndothelialCells
# 0       NaN         NaN               NaN           NaN               NaN
# 1  0.670869    0.139047          0.091245      0.050053          0.029782
# 2       NaN         NaN               NaN           NaN               NaN
# 3       NaN         NaN               NaN           NaN               NaN
# 4  0.729847    0.121844          0.060629      0.089211          0.022281
#
# [5 rows x 21 columns]

# %%
quality_control_data.columns
# Out:
# Index(['SampleID', 'Batch', 'TotalReads', 'MappedReads',
#        'UniquelyMappedUniqueReads', 'NonRedundantFraction', 'GCBias',
#        'CrossCorrelation', 'FragmentSize', 'NumberOfPeaks',
#        'MeanFoldEnrichment', 'MeanPeakWidth', 'SdPeakWidth',
#        'FractionOfReadsInPeaks', 'UniquelyMappedUniqueReadsInH3K9acDomains',
#        'CorrelationWithMedianSample', 'Neurons', 'Astrocytes',
#        'Oligodendrocytes', 'MyeloidCells', 'EndothelialCells'],
#       dtype='object')

# %%
clinical_data = pd.read_csv('../RSP_CL.csv')
clinical_data.head()
# Out:
#      projid Study  msex  educ  race  spanish  apoe_genotype age_at_visit_max  \
# 0  10101589   ROS   1.0  20.0   1.0      2.0           34.0              90+
# 1  86767530   MAP   0.0  10.0   1.0      2.0           33.0              90+
# 2   9650662   MAP   0.0  15.0   1.0      2.0           23.0              90+
# 3  50402855   MAP   0.0  21.0   1.0      2.0           33.0              90+
# 4  20544321   ROS   0.0  16.0   1.0      2.0           23.0              90+
#
#   age_first_ad_dx age_death  cts_mmse30_first_ad_dx  cts_mmse30_lv       pmi  \
# 0             90+       90+                    18.0            5.0  9.916667
# 1             90+       90+                    18.0           10.0  6.500000
# 2             90+       90+                     0.0            0.0  3.850000
# 3             NaN       NaN                     NaN           27.0       NaN
# 4             90+       NaN                    13.0           14.0       NaN
#
#    braaksc  ceradsc  cogdx  dcfdx_lv individualID
# 0      4.0      2.0    4.0       4.0     R6939144
# 1      4.0      2.0    4.0       4.0     R3893503
# 2      3.0      2.0    4.0       4.0     R8937093
# 3      NaN      NaN    NaN       1.0     R7139444
# 4      NaN      NaN    NaN       4.0     R4971237

# %%
clinical_data = clinical_data.rename(columns = {'projid': 'SampleID'})
clinical_data
# Out:
#       SampleID Study  msex  educ  race  spanish  apoe_genotype  \
# 0     10101589   ROS   1.0  20.0   1.0      2.0           34.0
# 1     86767530   MAP   0.0  10.0   1.0      2.0           33.0
# 2      9650662   MAP   0.0  15.0   1.0      2.0           23.0
# 3     50402855   MAP   0.0  21.0   1.0      2.0           33.0
# 4     20544321   ROS   0.0  16.0   1.0      2.0           23.0
# ...        ...   ...   ...   ...   ...      ...            ...
# 3579  22207815   ROS   0.0  18.0   2.0      2.0           23.0
# 3580  22207941   ROS   0.0  16.0   2.0      2.0           34.0
# 3581  49333806   MAP   0.0  12.0   2.0      2.0            NaN
# 3582  59720188   MAP   0.0  13.0   1.0      1.0            NaN
# 3583  90214403   NaN   NaN   NaN   NaN      NaN            NaN
#
#         age_at_visit_max age_first_ad_dx age_death  cts_mmse30_first_ad_dx  \
# 0                    90+             90+       90+                    18.0
# 1                    90+             90+       90+                    18.0
# 2                    90+             90+       90+                     0.0
# 3                    90+             NaN       NaN                     NaN
# 4                    90+             90+       NaN                    13.0
# ...                  ...             ...       ...                     ...
# 3579  57.653661875427787             NaN       NaN                     NaN
# 3580  56.651608487337441             NaN       NaN                     NaN
# 3581  56.599589322381931             NaN       NaN                     NaN
# 3582  54.622861054072551             NaN       NaN                     NaN
# 3583                 NaN             NaN       NaN                     NaN
#
#       cts_mmse30_lv       pmi  braaksc  ceradsc  cogdx  dcfdx_lv individualID
# 0               5.0  9.916667      4.0      2.0    4.0       4.0     R6939144
# 1              10.0  6.500000      4.0      2.0    4.0       4.0     R3893503
# 2               0.0  3.850000      3.0      2.0    4.0       4.0     R8937093
# 3              27.0       NaN      NaN      NaN    NaN       1.0     R7139444
# 4              14.0       NaN      NaN      NaN    NaN       4.0     R4971237
# ...             ...       ...      ...      ...    ...       ...          ...
# 3579           29.0       NaN      NaN      NaN    NaN       1.0     R5306025
# 3580           27.0       NaN      NaN      NaN    NaN       1.0     R6142763
# 3581           30.0       NaN      NaN      NaN    NaN       1.0     R4468842
# 3582           29.0       NaN      NaN      NaN    NaN       1.0     R9446033
# 3583            NaN       NaN      NaN      NaN    NaN       NaN     R5615105
#
# [3584 rows x 18 columns]

# %%
clinical_data = pd.merge(clinical_data, quality_control_data, on= 'SampleID', how ='left')

# %%
clinical_data.Batch
# Out:
# 0       45.0
# 1        NaN
# 2       50.0
# 3        NaN
# 4        NaN
#         ...
# 3579     NaN
# 3580     NaN
# 3581     NaN
# 3582     NaN
# 3583    29.0
# Name: Batch, Length: 3584, dtype: float64

# %%
clinical_data = clinical_data[~clinical_data.cogdx.isna()]
clinical_data
# Out:
#       SampleID Study  msex  educ  race  spanish  apoe_genotype  \
# 0     10101589   ROS   1.0  20.0   1.0      2.0           34.0
# 1     86767530   MAP   0.0  10.0   1.0      2.0           33.0
# 2      9650662   MAP   0.0  15.0   1.0      2.0           23.0
# 5     20630946   ROS   0.0  18.0   1.0      2.0           33.0
# 6     39136480   MAP   0.0  15.0   1.0      2.0           34.0
# ...        ...   ...   ...   ...   ...      ...            ...
# 3539  10417638   ROS   1.0  24.0   1.0      2.0           33.0
# 3543  50106028   MAP   1.0  18.0   1.0      2.0           33.0
# 3545  50502282   MAP   0.0  16.0   1.0      2.0           33.0
# 3553  74564064   MAP   1.0  12.0   1.0      1.0            NaN
# 3567  42589954   MAP   0.0  14.0   2.0      2.0           44.0
#
#         age_at_visit_max age_first_ad_dx           age_death  ...  \
# 0                    90+             90+                 90+  ...
# 1                    90+             90+                 90+  ...
# 2                    90+             90+                 90+  ...
# 5                    90+             90+                 90+  ...
# 6                    90+             90+                 90+  ...
# ...                  ...             ...                 ...  ...
# 3539  66.006844626967833             NaN  66.214921286789874  ...
# 3543  65.711156741957566             NaN  65.993155373032167  ...
# 3545  65.590691307323752             NaN  70.557152635181382  ...
# 3553  65.286789869952088             NaN  65.946611909650926  ...
# 3567  62.959616700889804             NaN  65.905544147843941  ...
#
#       MeanPeakWidth  SdPeakWidth  FractionOfReadsInPeaks  \
# 0       3080.988174  2520.339137                0.112093
# 1               NaN          NaN                     NaN
# 2       3595.801939  3419.790280                0.191745
# 5       3200.806379  2852.840966                0.170046
# 6               NaN          NaN                     NaN
# ...             ...          ...                     ...
# 3539            NaN          NaN                     NaN
# 3543    3133.893582  2600.375198                0.134832
# 3545            NaN          NaN                     NaN
# 3553            NaN          NaN                     NaN
# 3567            NaN          NaN                     NaN
#
#       UniquelyMappedUniqueReadsInH3K9acDomains  CorrelationWithMedianSample  \
# 0                                    4599491.0                     0.984938
# 1                                          NaN                          NaN
# 2                                    6791205.0                     0.990027
# 5                                    5285836.0                     0.989376
# 6                                          NaN                          NaN
# ...                                        ...                          ...
# 3539                                       NaN                          NaN
# 3543                                 4210106.0                     0.982032
# 3545                                       NaN                          NaN
# 3553                                       NaN                          NaN
# 3567                                       NaN                          NaN
#
#        Neurons  Astrocytes Oligodendrocytes  MyeloidCells  EndothelialCells
# 0     0.619105    0.181362         0.069196      0.068191          0.045071
# 1          NaN         NaN              NaN           NaN               NaN
# 2     0.737155    0.149615         0.048505      0.074465          0.028068
# 5     0.707102    0.134703         0.069619      0.067119          0.031984
# 6          NaN         NaN              NaN           NaN               NaN
# ...        ...         ...              ...           ...               ...
# 3539       NaN         NaN              NaN           NaN               NaN
# 3543       NaN         NaN              NaN           NaN               NaN
# 3545       NaN         NaN              NaN           NaN               NaN
# 3553       NaN         NaN              NaN           NaN               NaN
# 3567       NaN         NaN              NaN           NaN               NaN
#
# [1821 rows x 38 columns]

# %%
clinical_data.SampleID = clinical_data.SampleID.astype(str)

# %%
clinical_data = clinical_data[clinical_data.SampleID.isin(counts_data.columns.tolist())]

# %%
clinical_data
# Out:
#       SampleID Study  msex  educ  race  spanish  apoe_genotype  \
# 0     10101589   ROS   1.0  20.0   1.0      2.0           34.0
# 5     20630946   ROS   0.0  18.0   1.0      2.0           33.0
# 9     10433070   ROS   1.0  13.0   1.0      2.0           23.0
# 13    20969088   ROS   0.0  18.0   1.0      2.0           33.0
# 24    20907246   ROS   0.0  13.0   1.0      2.0           33.0
# ...        ...   ...   ...   ...   ...      ...            ...
# 3410  20656964   ROS   0.0  18.0   1.0      2.0           33.0
# 3456  11413170   ROS   1.0  18.0   1.0      2.0           23.0
# 3498  24039289   MAP   1.0  18.0   1.0      2.0           23.0
# 3528  11631558   ROS   1.0  12.0   1.0      2.0           23.0
# 3543  50106028   MAP   1.0  18.0   1.0      2.0           33.0
#
#         age_at_visit_max age_first_ad_dx           age_death  ...  \
# 0                    90+             90+                 90+  ...
# 5                    90+             90+                 90+  ...
# 9                    90+             90+                 90+  ...
# 13                   90+             NaN                 90+  ...
# 24                   90+             NaN                 90+  ...
# ...                  ...             ...                 ...  ...
# 3410  71.227926078028744             NaN  71.310061601642715  ...
# 3456  69.733059548254616             NaN  70.269678302532512  ...
# 3498  68.440793976728273             NaN  72.147843942505133  ...
# 3528  66.959616700889796             NaN  67.370294318959623  ...
# 3543  65.711156741957566             NaN  65.993155373032167  ...
#
#       MeanPeakWidth  SdPeakWidth  FractionOfReadsInPeaks  \
# 0       3080.988174  2520.339137                0.112093
# 5       3200.806379  2852.840966                0.170046
# 9       3078.231889  2772.556694                0.166198
# 13      3246.952232  2889.291774                0.144980
# 24      3236.902758  2785.796466                0.138938
# ...             ...          ...                     ...
# 3410    3261.571706  2853.455918                0.171889
# 3456    3699.652652  3409.152033                0.156311
# 3498    3098.697854  2707.973625                0.137716
# 3528    3129.318539  2610.011484                0.126121
# 3543    3133.893582  2600.375198                0.134832
#
#       UniquelyMappedUniqueReadsInH3K9acDomains  CorrelationWithMedianSample  \
# 0                                    4599491.0                     0.984938
# 5                                    5285836.0                     0.989376
# 9                                    4311853.0                     0.975757
# 13                                   6613035.0                     0.989392
# 24                                   4749378.0                     0.989393
# ...                                        ...                          ...
# 3410                                 5063051.0                     0.983510
# 3456                                 6571297.0                     0.984728
# 3498                                 4679830.0                     0.985259
# 3528                                 4446312.0                     0.985006
# 3543                                 4210106.0                     0.982032
#
#        Neurons  Astrocytes Oligodendrocytes  MyeloidCells  EndothelialCells
# 0     0.619105    0.181362         0.069196      0.068191          0.045071
# 5     0.707102    0.134703         0.069619      0.067119          0.031984
# 9     0.700101    0.167639         0.052717      0.070662          0.034329
# 13    0.710092    0.152077         0.069196      0.072918          0.040058
# 24    0.701765    0.123970         0.066592      0.072274          0.031717
# ...        ...         ...              ...           ...               ...
# 3410  0.723253    0.149496         0.044957      0.049850          0.035774
# 3456  0.718005    0.148203         0.038529      0.057982          0.011811
# 3498  0.630202    0.190408         0.072206      0.031654          0.031184
# 3528  0.676756    0.170481         0.070312      0.085687          0.040850
# 3543       NaN         NaN              NaN           NaN               NaN
#
# [642 rows x 38 columns]

# %%
clinical_data.columns
# Out:
# Index(['SampleID', 'Study', 'msex', 'educ', 'race', 'spanish', 'apoe_genotype',
#        'age_at_visit_max', 'age_first_ad_dx', 'age_death',
#        'cts_mmse30_first_ad_dx', 'cts_mmse30_lv', 'pmi', 'braaksc', 'ceradsc',
#        'cogdx', 'dcfdx_lv', 'individualID', 'Batch', 'TotalReads',
#        'MappedReads', 'UniquelyMappedUniqueReads', 'NonRedundantFraction',
#        'GCBias', 'CrossCorrelation', 'FragmentSize', 'NumberOfPeaks',
#        'MeanFoldEnrichment', 'MeanPeakWidth', 'SdPeakWidth',
#        'FractionOfReadsInPeaks', 'UniquelyMappedUniqueReadsInH3K9acDomains',
#        'CorrelationWithMedianSample', 'Neurons', 'Astrocytes',
#        'Oligodendrocytes', 'MyeloidCells', 'EndothelialCells'],
#       dtype='object')

# %%
clinical_data.braaksc
# Out:
# 0       4.0
# 5       3.0
# 9       4.0
# 13      4.0
# 24      3.0
#        ...
# 3410    3.0
# 3456    3.0
# 3498    2.0
# 3528    1.0
# 3543    0.0
# Name: braaksc, Length: 642, dtype: float64

# %%
s = set([str(i) for i in clinical_data.SampleID.tolist()])

# %%
len(s.intersection(set(counts_data.columns.tolist())))
# Out:
# 642

# %%
import matplotlib.pyplot as plt

labels = pd.DataFrame(clinical_data.braaksc.value_counts()).index.tolist()
sizes = pd.DataFrame(clinical_data.braaksc.value_counts())['count'].tolist()
fig, ax = plt.subplots(figsize=(10, 7))
ax.pie(sizes, labels=labels, textprops={'size': 'large'},autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7462ca5a61b0>,
#   <matplotlib.patches.Wedge at 0x7462c9b02420>,
#   <matplotlib.patches.Wedge at 0x7462c9b56600>,
#   <matplotlib.patches.Wedge at 0x7462c9b56c60>,
#   <matplotlib.patches.Wedge at 0x7462c9b572f0>,
#   <matplotlib.patches.Wedge at 0x7462c9b57950>,
#   <matplotlib.patches.Wedge at 0x7462c9b57fe0>],
#  [Text(0.6491738750498731, 0.8880164863068319, '4.0'),
#   Text(-1.0324289957712278, 0.3795923717500314, '3.0'),
#   Text(-0.3542206311214057, -1.0414066182274593, '5.0'),
#   Text(0.6792052148120974, -0.865263125397155, '2.0'),
#   Text(1.0286645786707382, -0.38967830910656653, '1.0'),
#   Text(1.0957356016482716, -0.0967651346327836, '0.0'),
#   Text(1.0996707581719345, -0.02691140318829902, '6.0')],
#  [Text(0.3540948409362944, 0.48437262889463556, '29.9%'),
#   Text(-0.5631430886024879, 0.2070503845909262, '29.0%'),
#   Text(-0.19321125333894856, -0.5680399735786141, '21.8%'),
#   Text(0.37047557171568946, -0.47196170476208443, '9.8%'),
#   Text(0.5610897701840389, -0.2125518049672181, '7.5%'),
#   Text(0.5976739645354208, -0.05278098252697287, '1.2%'),
#   Text(0.5998204135483278, -0.014678947193617646, '0.8%')])

# %%
clinical_data.columns
# Out:
# Index(['SampleID', 'Study', 'msex', 'educ', 'race', 'spanish', 'apoe_genotype',
#        'age_at_visit_max', 'age_first_ad_dx', 'age_death',
#        'cts_mmse30_first_ad_dx', 'cts_mmse30_lv', 'pmi', 'braaksc', 'ceradsc',
#        'cogdx', 'dcfdx_lv', 'individualID', 'Batch', 'TotalReads',
#        'MappedReads', 'UniquelyMappedUniqueReads', 'NonRedundantFraction',
#        'GCBias', 'CrossCorrelation', 'FragmentSize', 'NumberOfPeaks',
#        'MeanFoldEnrichment', 'MeanPeakWidth', 'SdPeakWidth',
#        'FractionOfReadsInPeaks', 'UniquelyMappedUniqueReadsInH3K9acDomains',
#        'CorrelationWithMedianSample', 'Neurons', 'Astrocytes',
#        'Oligodendrocytes', 'MyeloidCells', 'EndothelialCells'],
#       dtype='object')

# %%
clinical_data[['SampleID','cogdx', 'ceradsc']]
# Out:
#       SampleID  cogdx  ceradsc
# 0     10101589    4.0      2.0
# 5     20630946    4.0      4.0
# 9     10433070    5.0      2.0
# 13    20969088    2.0      2.0
# 24    20907246    2.0      3.0
# ...        ...    ...      ...
# 3410  20656964    1.0      2.0
# 3456  11413170    5.0      4.0
# 3498  24039289    2.0      4.0
# 3528  11631558    1.0      4.0
# 3543  50106028    2.0      4.0
#
# [642 rows x 3 columns]

# %%
Clinically_AD = set(clinical_data[clinical_data.cogdx == 4.0].SampleID)
Clinically_NCI = set(clinical_data[clinical_data.cogdx == 1.0].SampleID)

# %%
Pathological_AD = set(clinical_data[clinical_data.ceradsc == 1.0].SampleID)
Pathological_No_AD = set(clinical_data[clinical_data.ceradsc == 4.0].SampleID)

# %%
set1 = {0,1,2,3,4,5}
set2 = {3,4,5,6,10}
set3 = {0,5,6,7,8,9}
import pandas as pd
from upsetplot import plot
fig = plt.figure(figsize=(10, 3))
set_names = ['Clinically_AD', 'Clinically_NCI', 'Pathological_AD','Pathological_No_AD']
all_elems = Clincally_AD.union(Clinically_NCI).union(Pathological_AD).union(Pathological_No_AD)
df = pd.DataFrame([[e in Clinically_AD , e in Clinically_NCI, e in Pathological_AD, e in Pathological_No_AD] for e in all_elems], columns = set_names)
df_up = df.groupby(set_names).size()
plot(df_up, orientation='horizontal')
# Out:
# /home/anwer/.local/lib/python3.12/site-packages/upsetplot/plotting.py:795: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linewidth"].fillna(1, inplace=True)
# /home/anwer/.local/lib/python3.12/site-packages/upsetplot/plotting.py:796: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["facecolor"].fillna(self._facecolor, inplace=True)
# /home/anwer/.local/lib/python3.12/site-packages/upsetplot/plotting.py:797: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["edgecolor"].fillna(styles["facecolor"], inplace=True)
# /home/anwer/.local/lib/python3.12/site-packages/upsetplot/plotting.py:798: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linestyle"].fillna("solid", inplace=True)
# {'matrix': <Axes: >,
#  'shading': <Axes: >,
#  'totals': <Axes: >,
#  'intersections': <Axes: ylabel='Intersection size'>}
