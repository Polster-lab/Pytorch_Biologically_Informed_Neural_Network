# %% [markdown]
# # Index
# ### 1. Merging single cell data with clinical data (label)
#
#
#
# ### 2. Train-Test Split: Making sure train and test sets have different subjects

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#data = pd.read_csv('../preprocessed_data/mat.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data = pd.read_csv('../preprocessed_data/mat.csv')
#
# File ~/miniconda3/envs/myenv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/myenv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/miniconda3/envs/myenv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/myenv/lib/python3.8/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/miniconda3/envs/myenv/lib/python3.8/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../preprocessed_data/mat.csv'

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/usman/miniconda3/envs/myenv/lib/python3.8/site-packages (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /home/usman/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/usman/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/usman/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/usman/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in /home/usman/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /home/usman/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/usman/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/usman/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/usman/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/usman/miniconda3/envs/myenv/lib/python3.8/site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/usman/miniconda3/envs/myenv/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.19.2)
# Requirement already satisfied: six>=1.5 in /home/usman/miniconda3/envs/myenv/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#data.shape

# %%
#data

# %%
#pickle_file_path = '../preprocessed_data/count_matrix_microglia.pkl'
#data.to_pickle(pickle_file_path)

# %%
# Load the DataFrame from the pickle file
pickle_file_path = '../../preprocessed_data/microglia/count_matrix_microglia.pkl'
df_loaded = pd.read_pickle(pickle_file_path)

print("Pickle file has been loaded into a DataFrame:")
# Out:
# Pickle file has been loaded into a DataFrame:

# %%
df_loaded.set_index('Unnamed: 0', inplace=True)
df_loaded.index.name = 'gene_name'
df_loaded.head()
# Out:
#              AACTTTCAGGATGGTC.1.0  ACGGGCTCAATCAGAA.1.0  AGCGGTCAGATGTTAG.1.0  \
# gene_name
# MIR1302-2HG                     0                     0                     0
# FAM138A                         0                     0                     0
# OR4F5                           0                     0                     0
# AL627309.1                      0                     1                     0
# AL627309.3                      0                     0                     0
#
#              AGTGAGGGTGGTAACG.1.0  ATTACTCAGGAGTAGA.1.0  CAACCAACAAGCGTAG.1.0  \
# gene_name
# MIR1302-2HG                     0                     0                     0
# FAM138A                         0                     0                     0
# OR4F5                           0                     0                     0
# AL627309.1                      0                     0                     0
# AL627309.3                      0                     0                     0
#
#              CAGGTGCAGTCCATAC.1.0  CGATGGCGTCTTGTCC.1.0  CGATGGCGTTCTGTTT.1.0  \
# gene_name
# MIR1302-2HG                     0                     0                     0
# FAM138A                         0                     0                     0
# OR4F5                           0                     0                     0
# AL627309.1                      0                     0                     0
# AL627309.3                      0                     0                     0
#
#              CTGTTTACACATCCAA.1.0  ...  TTCACCGTCCTATTGT.16.14  \
# gene_name                          ...
# MIR1302-2HG                     0  ...                       0
# FAM138A                         0  ...                       0
# OR4F5                           0  ...                       0
# AL627309.1                      0  ...                       0
# AL627309.3                      0  ...                       0
#
#              TTCCACGAGGAAAGGT.16.14  TTCGATTAGTATGGCG.16.14  \
# gene_name
# MIR1302-2HG                       0                       0
# FAM138A                           0                       0
# OR4F5                             0                       0
# AL627309.1                        0                       0
# AL627309.3                        0                       0
#
#              TTCTAGTAGCATGTTC.16.14  TTGCGTCAGCTAGCCC.16.14  \
# gene_name
# MIR1302-2HG                       0                       0
# FAM138A                           0                       0
# OR4F5                             0                       0
# AL627309.1                        0                       0
# AL627309.3                        0                       0
#
#              TTGGGATCACGGCGTT.16.14  TTGGGTATCGTGTGAT.16.14  \
# gene_name
# MIR1302-2HG                       0                       0
# FAM138A                           0                       0
# OR4F5                             0                       0
# AL627309.1                        0                       0
# AL627309.3                        0                       0
#
#              TTGTGGAAGATTAGTG.16.14  TTTACCACACTGTCCT.16.14  \
# gene_name
# MIR1302-2HG                       0                       0
# FAM138A                           0                       0
# OR4F5                             0                       0
# AL627309.1                        0                       0
# AL627309.3                        0                       0
#
#              TTTACCAGTCAACACT.16.14
# gene_name
# MIR1302-2HG                       0
# FAM138A                           0
# OR4F5                             0
# AL627309.1                        0
# AL627309.3                        0
#
# [5 rows x 73061 columns]

# %%
df_loaded.shape
# Out:
# (33538, 73061)

# %%
row_sum = df_loaded.sum(axis=1)

print(row_sum)
# Out:
# gene_name
# MIR1302-2HG       2
# FAM138A           0
# OR4F5             0
# AL627309.1     3351
# AL627309.3        0
#                ...
# AC233755.2        0
# AC233755.1        0
# AC240274.1     2253
# AC213203.1        0
# FAM231C           0
# Length: 33538, dtype: int64

# %%
col_sum = df_loaded.sum(axis=0)
col_sum
# Out:
# AACTTTCAGGATGGTC.1.0      1398
# ACGGGCTCAATCAGAA.1.0      1963
# AGCGGTCAGATGTTAG.1.0      1742
# AGTGAGGGTGGTAACG.1.0      1870
# ATTACTCAGGAGTAGA.1.0      1451
#                           ...
# TTGGGATCACGGCGTT.16.14    2008
# TTGGGTATCGTGTGAT.16.14    2341
# TTGTGGAAGATTAGTG.16.14     685
# TTTACCACACTGTCCT.16.14    6627
# TTTACCAGTCAACACT.16.14    2698
# Length: 73061, dtype: int64

# %%
df_loaded.tail()
# Out:
#             AACTTTCAGGATGGTC.1.0  ACGGGCTCAATCAGAA.1.0  AGCGGTCAGATGTTAG.1.0  \
# gene_name
# AC233755.2                     0                     0                     0
# AC233755.1                     0                     0                     0
# AC240274.1                     0                     0                     0
# AC213203.1                     0                     0                     0
# FAM231C                        0                     0                     0
#
#             AGTGAGGGTGGTAACG.1.0  ATTACTCAGGAGTAGA.1.0  CAACCAACAAGCGTAG.1.0  \
# gene_name
# AC233755.2                     0                     0                     0
# AC233755.1                     0                     0                     0
# AC240274.1                     0                     0                     0
# AC213203.1                     0                     0                     0
# FAM231C                        0                     0                     0
#
#             CAGGTGCAGTCCATAC.1.0  CGATGGCGTCTTGTCC.1.0  CGATGGCGTTCTGTTT.1.0  \
# gene_name
# AC233755.2                     0                     0                     0
# AC233755.1                     0                     0                     0
# AC240274.1                     0                     0                     0
# AC213203.1                     0                     0                     0
# FAM231C                        0                     0                     0
#
#             CTGTTTACACATCCAA.1.0  ...  TTCACCGTCCTATTGT.16.14  \
# gene_name                         ...
# AC233755.2                     0  ...                       0
# AC233755.1                     0  ...                       0
# AC240274.1                     0  ...                       0
# AC213203.1                     0  ...                       0
# FAM231C                        0  ...                       0
#
#             TTCCACGAGGAAAGGT.16.14  TTCGATTAGTATGGCG.16.14  \
# gene_name
# AC233755.2                       0                       0
# AC233755.1                       0                       0
# AC240274.1                       0                       1
# AC213203.1                       0                       0
# FAM231C                          0                       0
#
#             TTCTAGTAGCATGTTC.16.14  TTGCGTCAGCTAGCCC.16.14  \
# gene_name
# AC233755.2                       0                       0
# AC233755.1                       0                       0
# AC240274.1                       0                       0
# AC213203.1                       0                       0
# FAM231C                          0                       0
#
#             TTGGGATCACGGCGTT.16.14  TTGGGTATCGTGTGAT.16.14  \
# gene_name
# AC233755.2                       0                       0
# AC233755.1                       0                       0
# AC240274.1                       0                       0
# AC213203.1                       0                       0
# FAM231C                          0                       0
#
#             TTGTGGAAGATTAGTG.16.14  TTTACCACACTGTCCT.16.14  \
# gene_name
# AC233755.2                       0                       0
# AC233755.1                       0                       0
# AC240274.1                       0                       1
# AC213203.1                       0                       0
# FAM231C                          0                       0
#
#             TTTACCAGTCAACACT.16.14
# gene_name
# AC233755.2                       0
# AC233755.1                       0
# AC240274.1                       0
# AC213203.1                       0
# FAM231C                          0
#
# [5 rows x 73061 columns]

# %%
clinical_data = pd.read_csv('/12tb_dsk1/danish/preprocessed_data/clinical/clinical_single_cell.csv')

# %%
clinical_data.head()
# Out:
#   individualID individualIdSource     sex  ethnicity       subject   projid  \
# 0     R2626559               Rush    male        NaN  ROSMAP-45310  1211411
# 1     R9936070               Rush    male        NaN  ROSMAP-34387  2899847
# 2     R2367199               Rush    male        NaN  ROSMAP-69520  3713990
# 3     R9891381               Rush  female        NaN  ROSMAP-53306  3889845
# 4     R9033345               Rush    male        NaN  ROSMAP-79585  6107196
#
#   Study  msex  educ  spanish  ...  age_death cts_mmse30_first_ad_dx  \
# 0   ROS   1.0  12.0      2.0  ...  85.549624                    NaN
# 1   MAP   1.0  14.0      2.0  ...  74.450376                    NaN
# 2   MAP   1.0  12.0      2.0  ...  87.928816                    NaN
# 3   MAP   0.0  13.0      2.0  ...  90.000000                    NaN
# 4   MAP   1.0  15.0      2.0  ...  90.000000                    NaN
#
#   cts_mmse30_lv  braaksc  ceradsc  cogdx  dcfdx_lv  clinical_diagnosis  \
# 0          24.0      1.0      4.0    4.0       4.0                  AD
# 1          27.0      2.0      2.0    3.0       3.0               False
# 2          30.0      4.0      2.0    1.0       1.0                 NCI
# 3          22.0      2.0      1.0    2.0       2.0               False
# 4          22.0      5.0      1.0    4.0       4.0                  AD
#
#    pathological_diagnosis  clinical_pathological_AD
# 0                   No AD                     False
# 1                   False                     False
# 2                   False                     False
# 3                      AD                     False
# 4                      AD           AD_with_Plaques
#
# [5 rows x 23 columns]

# %%
clinical_data.shape
# Out:
# (514, 23)

# %%
single_cell_metadata = pd.read_csv('../../preprocessed_data/microglia/metadata_microglia.csv')

# %%
single_cell_metadata
# Out:
#                       cell_id seq_folder  nUMI  nGene  percent.mt  \
# 0        AAACCCAAGACGATAT.4.3     ROSMAP  1199    863    0.667223
# 1      AAACCCAAGACGGATC.14.13     ROSMAP  2510   1581    1.434263
# 2      AAACCCAAGAGCCATG.10.13     ROSMAP   971    662    1.132853
# 3       AAACCCAAGAGCGACT.27.5     ROSMAP  1360    953    1.176471
# 4      AAACCCAAGCAACAGC.31.10     ROSMAP  3610   2024    1.274238
# ...                       ...        ...   ...    ...         ...
# 73056    TTTGTTGTCGCTGTCT.3.8     ROSMAP   995    745    1.708543
# 73057   TTTGTTGTCGTGTGGC.22.6     ROSMAP  1582   1142    0.063211
# 73058   TTTGTTGTCTAGACAC.20.9     ROSMAP  2142   1382    1.260504
# 73059   TTTGTTGTCTCAACCC.29.8     ROSMAP  4339   2189    0.622263
# 73060    TTTGTTGTCTCTTAAC.4.2     ROSMAP  5354   2536    0.074710
#
#       cell_type_high_resolution       subject Pathologic_diagnosis_of_AD  \
# 0                    Mic P2RY12  ROSMAP-86217                         no
# 1                    Mic P2RY12  ROSMAP-43251                        yes
# 2                    Mic P2RY12  ROSMAP-55106                         no
# 3                    Mic P2RY12  ROSMAP-45924                        yes
# 4                    Mic P2RY12  ROSMAP-98683                        yes
# ...                         ...           ...                        ...
# 73056                Mic P2RY12  ROSMAP-70249                         no
# 73057                Mic P2RY12  ROSMAP-75656                        yes
# 73058                Mic P2RY12  ROSMAP-38977                        yes
# 73059                Mic P2RY12  ROSMAP-75281                        yes
# 73060                Mic P2RY12  ROSMAP-33422                         no
#
#        log10GenesPerUMI individualID clinical_diagnosis  \
# 0              0.953616     R5636935              False
# 1              0.940953     R9679238                 AD
# 2              0.944309     R2506056                NCI
# 3              0.950712     R4249236              False
# 4              0.929362     R2144127                 AD
# ...                 ...          ...                ...
# 73056          0.958081     R4292728              False
# 73057          0.955758     R5546461                 AD
# 73058          0.942863     R2575548                NCI
# 73059          0.918308     R9596785              False
# 73060          0.912964     R4260171                NCI
#
#       pathological_diagnosis clinical_pathological_AD  \
# 0                      No AD                    False
# 1                      False                    False
# 2                      No AD      NCI_with_No_Plaques
# 3                      False                    False
# 4                      False                    False
# ...                      ...                      ...
# 73056                  No AD                    False
# 73057                     AD          AD_with_Plaques
# 73058                     AD                    False
# 73059                  False                    False
# 73060                  No AD      NCI_with_No_Plaques
#
#       train_test_clinical_and_pathological
# 0                                      NaN
# 1                                      NaN
# 2                                    train
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 73056                                  NaN
# 73057                                train
# 73058                                  NaN
# 73059                                  NaN
# 73060                                train
#
# [73061 rows x 14 columns]

# %%
single_cell_metadata['cell_id'] = single_cell_metadata['cell_id'].str.replace('-', '.')

# %%
single_cell_metadata
# Out:
#                       cell_id seq_folder  nUMI  nGene  percent.mt  \
# 0        AAACCCAAGACGATAT.4.3     ROSMAP  1199    863    0.667223
# 1      AAACCCAAGACGGATC.14.13     ROSMAP  2510   1581    1.434263
# 2      AAACCCAAGAGCCATG.10.13     ROSMAP   971    662    1.132853
# 3       AAACCCAAGAGCGACT.27.5     ROSMAP  1360    953    1.176471
# 4      AAACCCAAGCAACAGC.31.10     ROSMAP  3610   2024    1.274238
# ...                       ...        ...   ...    ...         ...
# 73056    TTTGTTGTCGCTGTCT.3.8     ROSMAP   995    745    1.708543
# 73057   TTTGTTGTCGTGTGGC.22.6     ROSMAP  1582   1142    0.063211
# 73058   TTTGTTGTCTAGACAC.20.9     ROSMAP  2142   1382    1.260504
# 73059   TTTGTTGTCTCAACCC.29.8     ROSMAP  4339   2189    0.622263
# 73060    TTTGTTGTCTCTTAAC.4.2     ROSMAP  5354   2536    0.074710
#
#       cell_type_high_resolution       subject Pathologic_diagnosis_of_AD  \
# 0                    Mic P2RY12  ROSMAP-86217                         no
# 1                    Mic P2RY12  ROSMAP-43251                        yes
# 2                    Mic P2RY12  ROSMAP-55106                         no
# 3                    Mic P2RY12  ROSMAP-45924                        yes
# 4                    Mic P2RY12  ROSMAP-98683                        yes
# ...                         ...           ...                        ...
# 73056                Mic P2RY12  ROSMAP-70249                         no
# 73057                Mic P2RY12  ROSMAP-75656                        yes
# 73058                Mic P2RY12  ROSMAP-38977                        yes
# 73059                Mic P2RY12  ROSMAP-75281                        yes
# 73060                Mic P2RY12  ROSMAP-33422                         no
#
#        log10GenesPerUMI individualID clinical_diagnosis  \
# 0              0.953616     R5636935              False
# 1              0.940953     R9679238                 AD
# 2              0.944309     R2506056                NCI
# 3              0.950712     R4249236              False
# 4              0.929362     R2144127                 AD
# ...                 ...          ...                ...
# 73056          0.958081     R4292728              False
# 73057          0.955758     R5546461                 AD
# 73058          0.942863     R2575548                NCI
# 73059          0.918308     R9596785              False
# 73060          0.912964     R4260171                NCI
#
#       pathological_diagnosis clinical_pathological_AD  \
# 0                      No AD                    False
# 1                      False                    False
# 2                      No AD      NCI_with_No_Plaques
# 3                      False                    False
# 4                      False                    False
# ...                      ...                      ...
# 73056                  No AD                    False
# 73057                     AD          AD_with_Plaques
# 73058                     AD                    False
# 73059                  False                    False
# 73060                  No AD      NCI_with_No_Plaques
#
#       train_test_clinical_and_pathological
# 0                                      NaN
# 1                                      NaN
# 2                                    train
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 73056                                  NaN
# 73057                                train
# 73058                                  NaN
# 73059                                  NaN
# 73060                                train
#
# [73061 rows x 14 columns]

# %%
set(df_loaded.columns) - set(single_cell_metadata['cell_id'])
#confirms that all sets in the single_cell_metadata are present in df_loaded
# Out:
# set()

# %%
set(single_cell_metadata['cell_id']) - set(df_loaded.columns)
# Out:
# set()

# %%
clinical_data
# Out:
#     individualID individualIdSource     sex  ethnicity       subject  \
# 0       R2626559               Rush    male        NaN  ROSMAP-45310
# 1       R9936070               Rush    male        NaN  ROSMAP-34387
# 2       R2367199               Rush    male        NaN  ROSMAP-69520
# 3       R9891381               Rush  female        NaN  ROSMAP-53306
# 4       R9033345               Rush    male        NaN  ROSMAP-79585
# ..           ...                ...     ...        ...           ...
# 509     R9738414               Rush  female        NaN  ROSMAP-90149
# 510     R7737688               Rush  female        NaN           NaN
# 511     R7844746               Rush    male        NaN           NaN
# 512     R6692433               Rush  female        NaN           NaN
# 513     R5309342               Rush  female        NaN           NaN
#
#        projid Study  msex  educ  spanish  ...  age_death  \
# 0     1211411   ROS   1.0  12.0      2.0  ...  85.549624
# 1     2899847   MAP   1.0  14.0      2.0  ...  74.450376
# 2     3713990   MAP   1.0  12.0      2.0  ...  87.928816
# 3     3889845   MAP   0.0  13.0      2.0  ...  90.000000
# 4     6107196   MAP   1.0  15.0      2.0  ...  90.000000
# ..        ...   ...   ...   ...      ...  ...        ...
# 509  20976799   ROS   0.0  18.0      2.0  ...  90.000000
# 510  69866926   MAP   0.0  13.0      2.0  ...  84.104038
# 511  29286432   ROS   1.0  24.0      2.0  ...  90.000000
# 512  48331728   MAP   0.0  14.0      2.0  ...  82.715948
# 513  10371937   MAP   0.0  18.0      2.0  ...  81.032170
#
#     cts_mmse30_first_ad_dx cts_mmse30_lv  braaksc  ceradsc  cogdx  dcfdx_lv  \
# 0                      NaN          24.0      1.0      4.0    4.0       4.0
# 1                      NaN          27.0      2.0      2.0    3.0       3.0
# 2                      NaN          30.0      4.0      2.0    1.0       1.0
# 3                      NaN          22.0      2.0      1.0    2.0       2.0
# 4                      NaN          22.0      5.0      1.0    4.0       4.0
# ..                     ...           ...      ...      ...    ...       ...
# 509                    NaN          19.0      2.0      4.0    2.0       2.0
# 510                   20.0           3.0      6.0      1.0    4.0       4.0
# 511                    NaN          29.0      5.0      2.0    2.0       2.0
# 512                    NaN          27.0      2.0      4.0    1.0       1.0
# 513                   25.0          25.0      5.0      1.0    4.0       4.0
#
#      clinical_diagnosis  pathological_diagnosis  clinical_pathological_AD
# 0                    AD                   No AD                     False
# 1                 False                   False                     False
# 2                   NCI                   False                     False
# 3                 False                      AD                     False
# 4                    AD                      AD           AD_with_Plaques
# ..                  ...                     ...                       ...
# 509               False                   No AD                     False
# 510                  AD                      AD           AD_with_Plaques
# 511               False                   False                     False
# 512                 NCI                   No AD       NCI_with_No_Plaques
# 513                  AD                      AD           AD_with_Plaques
#
# [514 rows x 23 columns]

# %%
len(set(single_cell_metadata.subject))
# Out:
# 425

# %%
set(clinical_data.subject)-set(single_cell_metadata.subject)
# Out:
# {'ROSMAP-35817', 'ROSMAP-83625', nan}

# %%
columns_list = clinical_data.columns.tolist()
print(columns_list)
# Out:
# ['individualID', 'individualIdSource', 'sex', 'ethnicity', 'subject', 'projid', 'Study', 'msex', 'educ', 'spanish', 'apoe_genotype', 'age_at_visit_max', 'age_first_ad_dx', 'age_death', 'cts_mmse30_first_ad_dx', 'cts_mmse30_lv', 'braaksc', 'ceradsc', 'cogdx', 'dcfdx_lv', 'clinical_diagnosis', 'pathological_diagnosis', 'clinical_pathological_AD']

# %%
columns_list = single_cell_metadata.columns.tolist()
print(columns_list)
# Out:
# ['cell_id', 'seq_folder', 'nUMI', 'nGene', 'percent.mt', 'cell_type_high_resolution', 'subject', 'Pathologic_diagnosis_of_AD', 'log10GenesPerUMI', 'individualID', 'clinical_diagnosis', 'pathological_diagnosis', 'clinical_pathological_AD', 'train_test_clinical_and_pathological']

# %%
single_cell_metadata = pd.merge(single_cell_metadata, clinical_data[['subject', 'individualID','clinical_diagnosis','pathological_diagnosis','clinical_pathological_AD']], on='subject', how='left')
#single_cell_metadata enriched with details about each subject

# %%
single_cell_metadata
# Out:
#                       cell_id seq_folder  nUMI  nGene  percent.mt  \
# 0        AAACCCAAGACGATAT.4.3     ROSMAP  1199    863    0.667223
# 1      AAACCCAAGACGGATC.14.13     ROSMAP  2510   1581    1.434263
# 2      AAACCCAAGAGCCATG.10.13     ROSMAP   971    662    1.132853
# 3       AAACCCAAGAGCGACT.27.5     ROSMAP  1360    953    1.176471
# 4      AAACCCAAGCAACAGC.31.10     ROSMAP  3610   2024    1.274238
# ...                       ...        ...   ...    ...         ...
# 89587   TTTGTTGTCGTGTGGC.22.6     ROSMAP  1582   1142    0.063211
# 89588   TTTGTTGTCTAGACAC.20.9     ROSMAP  2142   1382    1.260504
# 89589   TTTGTTGTCTCAACCC.29.8     ROSMAP  4339   2189    0.622263
# 89590    TTTGTTGTCTCTTAAC.4.2     ROSMAP  5354   2536    0.074710
# 89591    TTTGTTGTCTCTTAAC.4.2     ROSMAP  5354   2536    0.074710
#
#       cell_type_high_resolution       subject Pathologic_diagnosis_of_AD  \
# 0                    Mic P2RY12  ROSMAP-86217                         no
# 1                    Mic P2RY12  ROSMAP-43251                        yes
# 2                    Mic P2RY12  ROSMAP-55106                         no
# 3                    Mic P2RY12  ROSMAP-45924                        yes
# 4                    Mic P2RY12  ROSMAP-98683                        yes
# ...                         ...           ...                        ...
# 89587                Mic P2RY12  ROSMAP-75656                        yes
# 89588                Mic P2RY12  ROSMAP-38977                        yes
# 89589                Mic P2RY12  ROSMAP-75281                        yes
# 89590                Mic P2RY12  ROSMAP-33422                         no
# 89591                Mic P2RY12  ROSMAP-33422                         no
#
#        log10GenesPerUMI individualID_x clinical_diagnosis_x  \
# 0              0.953616       R5636935                False
# 1              0.940953       R9679238                   AD
# 2              0.944309       R2506056                  NCI
# 3              0.950712       R4249236                False
# 4              0.929362       R2144127                   AD
# ...                 ...            ...                  ...
# 89587          0.955758       R5546461                   AD
# 89588          0.942863       R2575548                  NCI
# 89589          0.918308       R9596785                False
# 89590          0.912964       R4260171                  NCI
# 89591          0.912964       R4260171                  NCI
#
#       pathological_diagnosis_x clinical_pathological_AD_x  \
# 0                        No AD                      False
# 1                        False                      False
# 2                        No AD        NCI_with_No_Plaques
# 3                        False                      False
# 4                        False                      False
# ...                        ...                        ...
# 89587                       AD            AD_with_Plaques
# 89588                       AD                      False
# 89589                    False                      False
# 89590                    No AD        NCI_with_No_Plaques
# 89591                    No AD        NCI_with_No_Plaques
#
#       train_test_clinical_and_pathological individualID_y  \
# 0                                      NaN       R5636935
# 1                                      NaN       R9679238
# 2                                    train       R2506056
# 3                                      NaN       R4249236
# 4                                      NaN       R2144127
# ...                                    ...            ...
# 89587                                train       R5546461
# 89588                                  NaN       R2575548
# 89589                                  NaN       R9596785
# 89590                                train       R4260171
# 89591                                train       R4260171
#
#       clinical_diagnosis_y pathological_diagnosis_y clinical_pathological_AD_y
# 0                    False                    No AD                      False
# 1                       AD                    False                      False
# 2                      NCI                    No AD        NCI_with_No_Plaques
# 3                    False                    False                      False
# 4                       AD                    False                      False
# ...                    ...                      ...                        ...
# 89587                   AD                       AD            AD_with_Plaques
# 89588                  NCI                       AD                      False
# 89589                False                    False                      False
# 89590                  NCI                    No AD        NCI_with_No_Plaques
# 89591                  NCI                    No AD        NCI_with_No_Plaques
#
# [89592 rows x 18 columns]

# %%
single_cell_metadata= single_cell_metadata.drop_duplicates()

# %%
try:
    single_cell_metadata.clinical_diagnosis.value_counts()
except:
    print('no_columns')
# Out:
# no_columns

# %%
try:
    single_cell_metadata.clinical_pathological_AD.value_counts()
except:
    print('no_columns')
# Out:
# no_columns

# %%
single_cell_metadata.Pathologic_diagnosis_of_AD.value_counts()
# Out:
# Pathologic_diagnosis_of_AD
# yes    40415
# no     32646
# Name: count, dtype: int64

# %%
single_cell_metadata.pathological_diagnosis.value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_426534/1165991751.py in ?()
# ----> 1 single_cell_metadata.pathological_diagnosis.value_counts()
#
# ~/miniconda3/envs/myenv/lib/python3.8/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'pathological_diagnosis'

# %%
rosmap_subject_single_cell_metadata = pd.merge(pd.DataFrame(single_cell_metadata.subject.value_counts()).reset_index(),clinical_data[['subject','clinical_pathological_AD']], on='subject', how='left')

# %%
rosmap_subject_single_cell_metadata

# %%
rosmap_subject_single_cell_metadata = rosmap_subject_single_cell_metadata[~rosmap_subject_single_cell_metadata.isin(['False']).any(axis=1)]
rosmap_subject_single_cell_metadata

# %%
import numpy as np
train_set_size = 0.80*np.sum(list(rosmap_subject_single_cell_metadata['count']))
test_set_size = 0.20*np.sum(list(rosmap_subject_single_cell_metadata['count']))

# %%
neg_samples = rosmap_subject_single_cell_metadata[rosmap_subject_single_cell_metadata.clinical_pathological_AD == 'NCI_with_No_Plaques']

# %%
pos_samples = rosmap_subject_single_cell_metadata[rosmap_subject_single_cell_metadata.clinical_pathological_AD == 'AD_with_Plaques']

# %%
neg_samples

# %%
pos_samples

# %%
# Sort the DataFrame by the count column
neg_samples = neg_samples.sort_values(by='count', ascending=True)
neg_samples['serial_number'] = [i for i in range(len(neg_samples))]
# Calculate cumulative counts
neg_samples['cumulative_count'] = neg_samples['count'].cumsum()

# Normalize cumulative counts to get percentages
neg_samples['cumulative_percent'] = neg_samples['cumulative_count'] / neg_samples['count'].sum() * 100

# Plot cumulative counts
plt.figure(figsize=(10, 6))
plt.plot(neg_samples['serial_number'], neg_samples['cumulative_percent'], marker='o', linestyle='-')

# Add 80 percent horizontal line
plt.axhline(y=80, color='r', linestyle='--')

# Add labels and title
plt.xlabel('Category')
plt.ylabel('Cumulative Percentage')
plt.title('Cumulative Plot with 80% Horizontal Line')
plt.grid(True)
plt.show()

# %%
neg_samples.tail(20)

# %%
import pandas as pd
import matplotlib.pyplot as plt



# Sort the DataFrame by the count column
pos_samples = pos_samples.sort_values(by='count', ascending=True)
pos_samples['serial_number'] = [i for i in range(len(pos_samples))]
# Calculate cumulative counts
pos_samples['cumulative_count'] = pos_samples['count'].cumsum()

# Normalize cumulative counts to get percentages
pos_samples['cumulative_percent'] = pos_samples['cumulative_count'] / pos_samples['count'].sum() * 100

# Plot cumulative counts
plt.figure(figsize=(10, 6))
plt.plot(pos_samples['serial_number'], pos_samples['cumulative_percent'], marker='o', linestyle='-')

# Add 80 percent horizontal line
plt.axhline(y=80, color='r', linestyle='--')

# Add labels and title
plt.xlabel('Category')
plt.ylabel('Cumulative Percentage')
plt.title('Cumulative Plot with 80% Horizontal Line')
plt.grid(True)
plt.show()

# %%
pos_samples.tail(20)

# %%
train_pos_samples = pos_samples[pos_samples.cumulative_percent<=80].subject
test_pos_samples = pos_samples[pos_samples.cumulative_percent>80].subject

# %%
test_pos_samples

# %%
train_neg_samples = neg_samples[neg_samples.cumulative_percent<=80].subject
test_neg_samples = neg_samples[neg_samples.cumulative_percent>80].subject

# %%
train_neg_samples

# %%
train_pos_samples

# %%
train_samples = list(train_pos_samples) + (list(train_neg_samples))
test_samples = list(test_pos_samples) + (list(test_neg_samples))

# %%
len(train_samples)

# %%
len(test_samples)

# %%
def return_train_test(x):
    if x in train_samples:
        return 'train'
    elif x in test_samples:
        return 'test'
    else:
        return np.nan

# %%
single_cell_metadata['train_test_clinical_and_pathological'] = single_cell_metadata.subject.apply(return_train_test)

# %%
single_cell_metadata.train_test_clinical_and_pathological.value_counts()

# %%
single_cell_metadata[single_cell_metadata.train_test_clinical_and_pathological=='train'].clinical_pathological_AD.value_counts()

# %%
single_cell_metadata[single_cell_metadata.train_test_clinical_and_pathological=='test'].clinical_pathological_AD.value_counts()

# %%
single_cell_metadata

# %%
single_cell_metadata.to_csv('../../preprocessed_data/metadata_microglia.csv', index = False)

# %%
'LRIG2' in df_loaded.index.tolist()

# %%
from biomart import BiomartServer

# Connect to the Ensembl Biomart server
server = BiomartServer("http://www.ensembl.org/biomart")

# Access the Ensembl Genes dataset for Homo sapiens
dataset = server.datasets['hsapiens_gene_ensembl']

# Query the dataset for Ensembl IDs and gene names
response = dataset.search({
    'attributes': [
        'ensembl_gene_id', 
        'external_gene_name'
    ]
})

# Convert the response to a dataframe
import pandas as pd
from io import StringIO

data = StringIO(response.text)

df = pd.read_csv(data, sep="\t",header = None)

# Display the first few rows of the dataframe
print(df.head())
# Nice

# %%
df.tail(20)

# %%
df_loaded

# %%
len(set(df_loaded.index.tolist()).intersection(set(df[1])))

# %%
df_loaded = df_loaded.reset_index()

# %%
import numpy as np
def return_ensemble_id(x):
    try:
        return df[df[1]==x][0].values[0]
    except: 
        return np.nan

# %%
x = df_loaded.reset_index().gene_name.apply(return_ensemble_id)

# %%
x.value_counts()

# %%
df_loaded['ensemble_gene_name'] = x

# %%
df_loaded = df_loaded.dropna()
df_loaded

# %%
df_loaded.set_index('ensemble_gene_name', inplace = True)

# %%
df_loaded

# %%
df[df[1]=='MT-ND5'][0].values[0]

# %%
df_loaded = df_loaded.drop(columns='gene_name')
df_loaded

# %%
pickle_file_path = '../preprocessed_data/count_matrix_ensemble_id_microglia.pkl'
df_loaded.to_pickle(pickle_file_path)

# %%
df_loaded

# %%
m = list(single_cell_metadata[single_cell_metadata.train_test_clinical_and_pathological == 'train'].cell_id)
label_train = list(single_cell_metadata[single_cell_metadata.train_test_clinical_and_pathological == 'train'].clinical_pathological_AD)
m[0:10]

# %%
label_train[0:10]

# %%
single_cell_metadata[single_cell_metadata.cell_id =='AAACCCAAGGTCGTCC.9.6'].clinical_pathological_AD

# %%
train_count_matrix = df_loaded[m]
train_count_matrix

# %%
n = list(single_cell_metadata[single_cell_metadata.train_test_clinical_and_pathological == 'test'].cell_id)
label_test = list(single_cell_metadata[single_cell_metadata.train_test_clinical_and_pathological == 'test'].clinical_pathological_AD)
n[0:10]

# %%
test_count_matrix = df_loaded[n]
test_count_matrix

# %%
single_cell_metadata[single_cell_metadata.cell_id =='AAACCCACAGCACAGA.23.6']

# %%
test_label = pd.DataFrame(label_test,columns=['diagnosis'])
train_label = pd.DataFrame(label_train,columns=['diagnosis'])

# %%
test_label.diagnosis.value_counts()

# %%
train_label.diagnosis.value_counts()

# %%
#/12tb_dsk1/usman/Single_Cell_Microglia_Project/preprocessed_data/train_test_set

test_count_matrix.to_csv('/12tb_dsk1/usman/Single_Cell_Microglia_Project/preprocessed_data/microglia/train_test_set/test_count_matrix.csv')
train_count_matrix.to_csv('/12tb_dsk1/usman/Single_Cell_Microglia_Project/preprocessed_data/microglia/train_test_set/train_count_matrix.csv')

test_label.to_csv('/12tb_dsk1/usman/Single_Cell_Microglia_Project/preprocessed_data/microglia/train_test_set/test_label.csv', index = False)
train_label.to_csv('/12tb_dsk1/usman/Single_Cell_Microglia_Project/preprocessed_data/microglia/train_test_set/train_label.csv', index = False)

# %%
rdata = pd.read_csv('/12tb_dsk1/usman/Single_Cell_Microglia_Project/preprocessed_data/microglia/train_test_set/train_count_matrix.csv')
qdata = pd.read_csv('/12tb_dsk1/usman/Single_Cell_Microglia_Project/preprocessed_data/microglia/train_test_set/test_count_matrix.csv')

# %%
rlabel = pd.read_csv('/12tb_dsk1/usman/Single_Cell_Microglia_Project/preprocessed_data/microglia/train_test_set/train_label.csv')
qlabel = pd.read_csv('/12tb_dsk1/usman/Single_Cell_Microglia_Project/preprocessed_data/microglia/train_test_set/test_label.csv')

# %%
rdata

# %%
rlabel

# %%
single_cell_metadata

# %% [markdown]
# # Correlation PCA

# %%
rdata = pd.read_csv('/12tb_dsk1/usman/Single_Cell_Microglia_Project/preprocessed_data/microglia/train_test_set/train_count_matrix.csv')
qdata = pd.read_csv('/12tb_dsk1/usman/Single_Cell_Microglia_Project/preprocessed_data/microglia/train_test_set/test_count_matrix.csv')
rdata.set_index('ensemble_gene_name', inplace =  True)
qdata.set_index('ensemble_gene_name', inplace =  True)
merged_data_clinical_pathological = pd.concat([rdata.T,qdata.T])

# %%
merged_data_clinical_pathological
# Out:
# ensemble_gene_name      ENSG00000243485  ENSG00000237613  ENSG00000186092  \
# AAACCCAAGAGCCATG.10.13                0                0                0
# AAACCCAAGCAGTACG.2.9                  0                0                0
# AAACCCAAGCTGCCTG.9.14                 0                0                0
# AAACCCAAGGCAGGGA.9.9                  0                0                0
# AAACCCAAGGCATGGT.13.12                0                0                0
# ...                                 ...              ...              ...
# TTTGGAGTCTTAGGAC.32.9                 0                0                0
# TTTGTTGAGATCACTC.6.2                  0                0                0
# TTTGTTGAGCGGATCA.8.11                 0                0                0
# TTTGTTGCACAGCTTA.20.11                0                0                0
# TTTGTTGGTCATACCA.6.13                 0                0                0
#
# ensemble_gene_name      ENSG00000284733  ENSG00000284662  ENSG00000177757  \
# AAACCCAAGAGCCATG.10.13                0                0                0
# AAACCCAAGCAGTACG.2.9                  0                0                0
# AAACCCAAGCTGCCTG.9.14                 0                0                0
# AAACCCAAGGCAGGGA.9.9                  0                0                0
# AAACCCAAGGCATGGT.13.12                0                0                0
# ...                                 ...              ...              ...
# TTTGGAGTCTTAGGAC.32.9                 0                0                0
# TTTGTTGAGATCACTC.6.2                  0                0                0
# TTTGTTGAGCGGATCA.8.11                 0                0                0
# TTTGTTGCACAGCTTA.20.11                0                0                0
# TTTGTTGGTCATACCA.6.13                 0                0                0
#
# ensemble_gene_name      ENSG00000225880  ENSG00000230368  ENSG00000187634  \
# AAACCCAAGAGCCATG.10.13                0                0                0
# AAACCCAAGCAGTACG.2.9                  0                0                0
# AAACCCAAGCTGCCTG.9.14                 0                0                0
# AAACCCAAGGCAGGGA.9.9                  0                0                0
# AAACCCAAGGCATGGT.13.12                0                0                0
# ...                                 ...              ...              ...
# TTTGGAGTCTTAGGAC.32.9                 0                0                0
# TTTGTTGAGATCACTC.6.2                  0                0                0
# TTTGTTGAGCGGATCA.8.11                 0                0                0
# TTTGTTGCACAGCTTA.20.11                0                0                0
# TTTGTTGGTCATACCA.6.13                 0                0                0
#
# ensemble_gene_name      ENSG00000188976  ...  ENSG00000228253  \
# AAACCCAAGAGCCATG.10.13                0  ...                0
# AAACCCAAGCAGTACG.2.9                  0  ...                0
# AAACCCAAGCTGCCTG.9.14                 0  ...                0
# AAACCCAAGGCAGGGA.9.9                  0  ...                0
# AAACCCAAGGCATGGT.13.12                0  ...                0
# ...                                 ...  ...              ...
# TTTGGAGTCTTAGGAC.32.9                 0  ...                0
# TTTGTTGAGATCACTC.6.2                  0  ...                0
# TTTGTTGAGCGGATCA.8.11                 0  ...                0
# TTTGTTGCACAGCTTA.20.11                1  ...                0
# TTTGTTGGTCATACCA.6.13                 1  ...                0
#
# ensemble_gene_name      ENSG00000198899  ENSG00000198938  ENSG00000198840  \
# AAACCCAAGAGCCATG.10.13                0                1                1
# AAACCCAAGCAGTACG.2.9                  0                0                1
# AAACCCAAGCTGCCTG.9.14                 0                1                0
# AAACCCAAGGCAGGGA.9.9                  1                2                2
# AAACCCAAGGCATGGT.13.12                2                1                0
# ...                                 ...              ...              ...
# TTTGGAGTCTTAGGAC.32.9                 2                6                4
# TTTGTTGAGATCACTC.6.2                  1                7                0
# TTTGTTGAGCGGATCA.8.11                 0                1                0
# TTTGTTGCACAGCTTA.20.11                3                1                0
# TTTGTTGGTCATACCA.6.13                 2                0                1
#
# ensemble_gene_name      ENSG00000212907  ENSG00000198886  ENSG00000198786  \
# AAACCCAAGAGCCATG.10.13                0                2                0
# AAACCCAAGCAGTACG.2.9                  0                0                0
# AAACCCAAGCTGCCTG.9.14                 0                1                0
# AAACCCAAGGCAGGGA.9.9                  0                0                0
# AAACCCAAGGCATGGT.13.12                0                0                0
# ...                                 ...              ...              ...
# TTTGGAGTCTTAGGAC.32.9                 0                1                0
# TTTGTTGAGATCACTC.6.2                  0                1                0
# TTTGTTGAGCGGATCA.8.11                 0                0                0
# TTTGTTGCACAGCTTA.20.11                1                2                0
# TTTGTTGGTCATACCA.6.13                 0                0                0
#
# ensemble_gene_name      ENSG00000198695  ENSG00000198727  ENSG00000274847
# AAACCCAAGAGCCATG.10.13                0                1                0
# AAACCCAAGCAGTACG.2.9                  0                1                0
# AAACCCAAGCTGCCTG.9.14                 0                0                0
# AAACCCAAGGCAGGGA.9.9                  0                2                0
# AAACCCAAGGCATGGT.13.12                0                0                0
# ...                                 ...              ...              ...
# TTTGGAGTCTTAGGAC.32.9                 0                5                0
# TTTGTTGAGATCACTC.6.2                  0                1                0
# TTTGTTGAGCGGATCA.8.11                 0                0                0
# TTTGTTGCACAGCTTA.20.11                0                1                0
# TTTGTTGGTCATACCA.6.13                 0                0                0
#
# [25877 rows x 22500 columns]

# %%
single_cell_metadata = pd.read_csv('../../preprocessed_data/microglia/metadata_microglia.csv')
single_cell_metadata
# Out:
#                       cell_id seq_folder  nUMI  nGene  percent.mt  \
# 0        AAACCCAAGACGATAT.4.3     ROSMAP  1199    863    0.667223
# 1      AAACCCAAGACGGATC.14.13     ROSMAP  2510   1581    1.434263
# 2      AAACCCAAGAGCCATG.10.13     ROSMAP   971    662    1.132853
# 3       AAACCCAAGAGCGACT.27.5     ROSMAP  1360    953    1.176471
# 4      AAACCCAAGCAACAGC.31.10     ROSMAP  3610   2024    1.274238
# ...                       ...        ...   ...    ...         ...
# 73056    TTTGTTGTCGCTGTCT.3.8     ROSMAP   995    745    1.708543
# 73057   TTTGTTGTCGTGTGGC.22.6     ROSMAP  1582   1142    0.063211
# 73058   TTTGTTGTCTAGACAC.20.9     ROSMAP  2142   1382    1.260504
# 73059   TTTGTTGTCTCAACCC.29.8     ROSMAP  4339   2189    0.622263
# 73060    TTTGTTGTCTCTTAAC.4.2     ROSMAP  5354   2536    0.074710
#
#       cell_type_high_resolution       subject Pathologic_diagnosis_of_AD  \
# 0                    Mic P2RY12  ROSMAP-86217                         no
# 1                    Mic P2RY12  ROSMAP-43251                        yes
# 2                    Mic P2RY12  ROSMAP-55106                         no
# 3                    Mic P2RY12  ROSMAP-45924                        yes
# 4                    Mic P2RY12  ROSMAP-98683                        yes
# ...                         ...           ...                        ...
# 73056                Mic P2RY12  ROSMAP-70249                         no
# 73057                Mic P2RY12  ROSMAP-75656                        yes
# 73058                Mic P2RY12  ROSMAP-38977                        yes
# 73059                Mic P2RY12  ROSMAP-75281                        yes
# 73060                Mic P2RY12  ROSMAP-33422                         no
#
#        log10GenesPerUMI individualID clinical_diagnosis  \
# 0              0.953616     R5636935              False
# 1              0.940953     R9679238                 AD
# 2              0.944309     R2506056                NCI
# 3              0.950712     R4249236              False
# 4              0.929362     R2144127                 AD
# ...                 ...          ...                ...
# 73056          0.958081     R4292728              False
# 73057          0.955758     R5546461                 AD
# 73058          0.942863     R2575548                NCI
# 73059          0.918308     R9596785              False
# 73060          0.912964     R4260171                NCI
#
#       pathological_diagnosis clinical_pathological_AD  \
# 0                      No AD                    False
# 1                      False                    False
# 2                      No AD      NCI_with_No_Plaques
# 3                      False                    False
# 4                      False                    False
# ...                      ...                      ...
# 73056                  No AD                    False
# 73057                     AD          AD_with_Plaques
# 73058                     AD                    False
# 73059                  False                    False
# 73060                  No AD      NCI_with_No_Plaques
#
#       train_test_clinical_and_pathological
# 0                                      NaN
# 1                                      NaN
# 2                                    train
# 3                                      NaN
# 4                                      NaN
# ...                                    ...
# 73056                                  NaN
# 73057                                train
# 73058                                  NaN
# 73059                                  NaN
# 73060                                train
#
# [73061 rows x 14 columns]

# %%
clinical_data = pd.read_csv('/12tb_dsk1/danish/preprocessed_data/clinical/clinical_single_cell.csv')
clinical_data
# Out:
#     individualID individualIdSource     sex  ethnicity       subject  \
# 0       R2626559               Rush    male        NaN  ROSMAP-45310
# 1       R9936070               Rush    male        NaN  ROSMAP-34387
# 2       R2367199               Rush    male        NaN  ROSMAP-69520
# 3       R9891381               Rush  female        NaN  ROSMAP-53306
# 4       R9033345               Rush    male        NaN  ROSMAP-79585
# ..           ...                ...     ...        ...           ...
# 509     R9738414               Rush  female        NaN  ROSMAP-90149
# 510     R7737688               Rush  female        NaN           NaN
# 511     R7844746               Rush    male        NaN           NaN
# 512     R6692433               Rush  female        NaN           NaN
# 513     R5309342               Rush  female        NaN           NaN
#
#        projid Study  msex  educ  spanish  ...  age_death  \
# 0     1211411   ROS   1.0  12.0      2.0  ...  85.549624
# 1     2899847   MAP   1.0  14.0      2.0  ...  74.450376
# 2     3713990   MAP   1.0  12.0      2.0  ...  87.928816
# 3     3889845   MAP   0.0  13.0      2.0  ...  90.000000
# 4     6107196   MAP   1.0  15.0      2.0  ...  90.000000
# ..        ...   ...   ...   ...      ...  ...        ...
# 509  20976799   ROS   0.0  18.0      2.0  ...  90.000000
# 510  69866926   MAP   0.0  13.0      2.0  ...  84.104038
# 511  29286432   ROS   1.0  24.0      2.0  ...  90.000000
# 512  48331728   MAP   0.0  14.0      2.0  ...  82.715948
# 513  10371937   MAP   0.0  18.0      2.0  ...  81.032170
#
#     cts_mmse30_first_ad_dx cts_mmse30_lv  braaksc  ceradsc  cogdx  dcfdx_lv  \
# 0                      NaN          24.0      1.0      4.0    4.0       4.0
# 1                      NaN          27.0      2.0      2.0    3.0       3.0
# 2                      NaN          30.0      4.0      2.0    1.0       1.0
# 3                      NaN          22.0      2.0      1.0    2.0       2.0
# 4                      NaN          22.0      5.0      1.0    4.0       4.0
# ..                     ...           ...      ...      ...    ...       ...
# 509                    NaN          19.0      2.0      4.0    2.0       2.0
# 510                   20.0           3.0      6.0      1.0    4.0       4.0
# 511                    NaN          29.0      5.0      2.0    2.0       2.0
# 512                    NaN          27.0      2.0      4.0    1.0       1.0
# 513                   25.0          25.0      5.0      1.0    4.0       4.0
#
#      clinical_diagnosis  pathological_diagnosis  clinical_pathological_AD
# 0                    AD                   No AD                     False
# 1                 False                   False                     False
# 2                   NCI                   False                     False
# 3                 False                      AD                     False
# 4                    AD                      AD           AD_with_Plaques
# ..                  ...                     ...                       ...
# 509               False                   No AD                     False
# 510                  AD                      AD           AD_with_Plaques
# 511               False                   False                     False
# 512                 NCI                   No AD       NCI_with_No_Plaques
# 513                  AD                      AD           AD_with_Plaques
#
# [514 rows x 23 columns]

# %%
clinical_data.age_first_ad_dx.value_counts()
# Out:
# age_first_ad_dx
# 90+                   40
# 77.097878165639969     3
# 79.991786447638603     2
# 79.89596167008898      2
# 82.35455167693361      2
#                       ..
# 81.51403148528405      1
# 83.036276522929498     1
# 73.051334702258728     1
# 82.472279260780283     1
# 85.62354551676934      1
# Name: count, Length: 107, dtype: int64

# %%
single_cell_metadata = pd.merge(single_cell_metadata,clinical_data[['subject','age_death','msex','educ','age_first_ad_dx','cogdx','ceradsc','braaksc','apoe_genotype']], on = 'subject', how = 'left')

# %%
single_cell_metadata = single_cell_metadata.drop(columns=['apoe_genotype'])
single_cell_metadata
# Out:
#                       cell_id seq_folder  nUMI  nGene  percent.mt  \
# 0        AAACCCAAGACGATAT.4.3     ROSMAP  1199    863    0.667223
# 1      AAACCCAAGACGGATC.14.13     ROSMAP  2510   1581    1.434263
# 2      AAACCCAAGAGCCATG.10.13     ROSMAP   971    662    1.132853
# 3       AAACCCAAGAGCGACT.27.5     ROSMAP  1360    953    1.176471
# 4      AAACCCAAGCAACAGC.31.10     ROSMAP  3610   2024    1.274238
# ...                       ...        ...   ...    ...         ...
# 89587   TTTGTTGTCGTGTGGC.22.6     ROSMAP  1582   1142    0.063211
# 89588   TTTGTTGTCTAGACAC.20.9     ROSMAP  2142   1382    1.260504
# 89589   TTTGTTGTCTCAACCC.29.8     ROSMAP  4339   2189    0.622263
# 89590    TTTGTTGTCTCTTAAC.4.2     ROSMAP  5354   2536    0.074710
# 89591    TTTGTTGTCTCTTAAC.4.2     ROSMAP  5354   2536    0.074710
#
#       cell_type_high_resolution       subject Pathologic_diagnosis_of_AD  \
# 0                    Mic P2RY12  ROSMAP-86217                         no
# 1                    Mic P2RY12  ROSMAP-43251                        yes
# 2                    Mic P2RY12  ROSMAP-55106                         no
# 3                    Mic P2RY12  ROSMAP-45924                        yes
# 4                    Mic P2RY12  ROSMAP-98683                        yes
# ...                         ...           ...                        ...
# 89587                Mic P2RY12  ROSMAP-75656                        yes
# 89588                Mic P2RY12  ROSMAP-38977                        yes
# 89589                Mic P2RY12  ROSMAP-75281                        yes
# 89590                Mic P2RY12  ROSMAP-33422                         no
# 89591                Mic P2RY12  ROSMAP-33422                         no
#
#        log10GenesPerUMI individualID  ... pathological_diagnosis  \
# 0              0.953616     R5636935  ...                  No AD
# 1              0.940953     R9679238  ...                  False
# 2              0.944309     R2506056  ...                  No AD
# 3              0.950712     R4249236  ...                  False
# 4              0.929362     R2144127  ...                  False
# ...                 ...          ...  ...                    ...
# 89587          0.955758     R5546461  ...                     AD
# 89588          0.942863     R2575548  ...                     AD
# 89589          0.918308     R9596785  ...                  False
# 89590          0.912964     R4260171  ...                  No AD
# 89591          0.912964     R4260171  ...                  No AD
#
#       clinical_pathological_AD train_test_clinical_and_pathological  \
# 0                        False                                  NaN
# 1                        False                                  NaN
# 2          NCI_with_No_Plaques                                train
# 3                        False                                  NaN
# 4                        False                                  NaN
# ...                        ...                                  ...
# 89587          AD_with_Plaques                                train
# 89588                    False                                  NaN
# 89589                    False                                  NaN
# 89590      NCI_with_No_Plaques                                train
# 89591      NCI_with_No_Plaques                                train
#
#        age_death  msex  educ     age_first_ad_dx cogdx  ceradsc  braaksc
# 0      83.975359   0.0  10.0  76.709103353867221   2.0      4.0      2.0
# 1      82.370979   1.0  24.0  81.648186173853531   4.0      2.0      3.0
# 2      80.435318   0.0  21.0                 NaN   1.0      4.0      3.0
# 3      84.364134   1.0  21.0                 NaN   2.0      2.0      3.0
# 4      89.374401   0.0  12.0  85.861738535249827   4.0      2.0      5.0
# ...          ...   ...   ...                 ...   ...      ...      ...
# 89587  90.000000   0.0  14.0                 90+   4.0      1.0      3.0
# 89588  84.208077   1.0  18.0                 NaN   1.0      1.0      4.0
# 89589  85.850787   1.0  20.0                 NaN   2.0      2.0      4.0
# 89590  78.234086   1.0  16.0                 NaN   1.0      4.0      1.0
# 89591  78.234086   1.0  16.0                 NaN   1.0      4.0      1.0
#
# [89592 rows x 21 columns]

# %%
covariates_dataframe = pd.merge(merged_data_clinical_pathological.reset_index()['index'],single_cell_metadata[['cell_id','subject','age_death','msex','educ','age_first_ad_dx','cogdx','ceradsc','braaksc',
                                                                                        'clinical_pathological_AD']] , left_on='index', right_on='cell_id', how='inner')

# %%
covariates_dataframe = covariates_dataframe.drop_duplicates()
covariates_dataframe.set_index('cell_id',inplace = True)
covariates_dataframe.head()
# Out:
#                                          index       subject  age_death  msex  \
# cell_id
# AAACCCAAGAGCCATG.10.13  AAACCCAAGAGCCATG.10.13  ROSMAP-55106  80.435318   0.0
# AAACCCAAGCAGTACG.2.9      AAACCCAAGCAGTACG.2.9  ROSMAP-82353  81.911020   0.0
# AAACCCAAGCTGCCTG.9.14    AAACCCAAGCTGCCTG.9.14  ROSMAP-97833  83.537303   1.0
# AAACCCAAGGCAGGGA.9.9      AAACCCAAGGCAGGGA.9.9  ROSMAP-14875  81.859001   0.0
# AAACCCAAGGCATGGT.13.12  AAACCCAAGGCATGGT.13.12  ROSMAP-99585  90.000000   1.0
#
#                         educ     age_first_ad_dx  cogdx  ceradsc  braaksc  \
# cell_id
# AAACCCAAGAGCCATG.10.13  21.0                 NaN    1.0      4.0      3.0
# AAACCCAAGCAGTACG.2.9    16.0                 NaN    1.0      4.0      4.0
# AAACCCAAGCTGCCTG.9.14   21.0                 NaN    1.0      4.0      4.0
# AAACCCAAGGCAGGGA.9.9    20.0                 NaN    1.0      4.0      1.0
# AAACCCAAGGCATGGT.13.12  21.0  87.331964407939765    4.0      1.0      4.0
#
#                        clinical_pathological_AD
# cell_id
# AAACCCAAGAGCCATG.10.13      NCI_with_No_Plaques
# AAACCCAAGCAGTACG.2.9        NCI_with_No_Plaques
# AAACCCAAGCTGCCTG.9.14       NCI_with_No_Plaques
# AAACCCAAGGCAGGGA.9.9        NCI_with_No_Plaques
# AAACCCAAGGCATGGT.13.12          AD_with_Plaques

# %%
try:
    covariates_dataframe.drop(columns=['index'],inplace = True)
except:
    print('no such columns, probably I am running this snippet second time')
covariates_dataframe.head()
# Out:
#                              subject  age_death  msex  educ  \
# cell_id
# AAACCCAAGAGCCATG.10.13  ROSMAP-55106  80.435318   0.0  21.0
# AAACCCAAGCAGTACG.2.9    ROSMAP-82353  81.911020   0.0  16.0
# AAACCCAAGCTGCCTG.9.14   ROSMAP-97833  83.537303   1.0  21.0
# AAACCCAAGGCAGGGA.9.9    ROSMAP-14875  81.859001   0.0  20.0
# AAACCCAAGGCATGGT.13.12  ROSMAP-99585  90.000000   1.0  21.0
#
#                            age_first_ad_dx  cogdx  ceradsc  braaksc  \
# cell_id
# AAACCCAAGAGCCATG.10.13                 NaN    1.0      4.0      3.0
# AAACCCAAGCAGTACG.2.9                   NaN    1.0      4.0      4.0
# AAACCCAAGCTGCCTG.9.14                  NaN    1.0      4.0      4.0
# AAACCCAAGGCAGGGA.9.9                   NaN    1.0      4.0      1.0
# AAACCCAAGGCATGGT.13.12  87.331964407939765    4.0      1.0      4.0
#
#                        clinical_pathological_AD
# cell_id
# AAACCCAAGAGCCATG.10.13      NCI_with_No_Plaques
# AAACCCAAGCAGTACG.2.9        NCI_with_No_Plaques
# AAACCCAAGCTGCCTG.9.14       NCI_with_No_Plaques
# AAACCCAAGGCAGGGA.9.9        NCI_with_No_Plaques
# AAACCCAAGGCATGGT.13.12          AD_with_Plaques

# %%
covariates_dataframe = covariates_dataframe.sort_index()
covariates_dataframe = covariates_dataframe[['age_death','msex','educ','cogdx','ceradsc','braaksc']]
covariates_dataframe = covariates_dataframe.astype(float)
covariates_dataframe
# Out:
#                         age_death  msex  educ  cogdx  ceradsc  braaksc
# cell_id
# AAACCCAAGAGCCATG.10.13  80.435318   0.0  21.0    1.0      4.0      3.0
# AAACCCAAGCAGTACG.2.9    81.911020   0.0  16.0    1.0      4.0      4.0
# AAACCCAAGCTGCCTG.9.14   83.537303   1.0  21.0    1.0      4.0      4.0
# AAACCCAAGGCAGGGA.9.9    81.859001   0.0  20.0    1.0      4.0      1.0
# AAACCCAAGGCATGGT.13.12  90.000000   1.0  21.0    4.0      1.0      4.0
# ...                           ...   ...   ...    ...      ...      ...
# TTTGTTGTCACGGTCG.8.6    89.086927   1.0  12.0    1.0      4.0      3.0
# TTTGTTGTCAGAACCT.45.2   87.419576   1.0  23.0    4.0      1.0      6.0
# TTTGTTGTCCAGTGCG.3.5    81.911020   0.0  16.0    1.0      4.0      4.0
# TTTGTTGTCGTGTGGC.22.6   90.000000   0.0  14.0    4.0      1.0      3.0
# TTTGTTGTCTCTTAAC.4.2    78.234086   1.0  16.0    1.0      4.0      1.0
#
# [25877 rows x 6 columns]

# %%
merged_data_clinical_pathological = merged_data_clinical_pathological.sort_index()
merged_data_clinical_pathological
# Out:
# ensemble_gene_name      ENSG00000243485  ENSG00000237613  ENSG00000186092  \
# AAACCCAAGAGCCATG.10.13                0                0                0
# AAACCCAAGCAGTACG.2.9                  0                0                0
# AAACCCAAGCTGCCTG.9.14                 0                0                0
# AAACCCAAGGCAGGGA.9.9                  0                0                0
# AAACCCAAGGCATGGT.13.12                0                0                0
# ...                                 ...              ...              ...
# TTTGTTGTCACGGTCG.8.6                  0                0                0
# TTTGTTGTCAGAACCT.45.2                 0                0                0
# TTTGTTGTCCAGTGCG.3.5                  0                0                0
# TTTGTTGTCGTGTGGC.22.6                 0                0                0
# TTTGTTGTCTCTTAAC.4.2                  0                0                0
#
# ensemble_gene_name      ENSG00000284733  ENSG00000284662  ENSG00000177757  \
# AAACCCAAGAGCCATG.10.13                0                0                0
# AAACCCAAGCAGTACG.2.9                  0                0                0
# AAACCCAAGCTGCCTG.9.14                 0                0                0
# AAACCCAAGGCAGGGA.9.9                  0                0                0
# AAACCCAAGGCATGGT.13.12                0                0                0
# ...                                 ...              ...              ...
# TTTGTTGTCACGGTCG.8.6                  0                0                0
# TTTGTTGTCAGAACCT.45.2                 0                0                0
# TTTGTTGTCCAGTGCG.3.5                  0                0                0
# TTTGTTGTCGTGTGGC.22.6                 0                0                0
# TTTGTTGTCTCTTAAC.4.2                  0                0                0
#
# ensemble_gene_name      ENSG00000225880  ENSG00000230368  ENSG00000187634  \
# AAACCCAAGAGCCATG.10.13                0                0                0
# AAACCCAAGCAGTACG.2.9                  0                0                0
# AAACCCAAGCTGCCTG.9.14                 0                0                0
# AAACCCAAGGCAGGGA.9.9                  0                0                0
# AAACCCAAGGCATGGT.13.12                0                0                0
# ...                                 ...              ...              ...
# TTTGTTGTCACGGTCG.8.6                  0                0                0
# TTTGTTGTCAGAACCT.45.2                 0                0                0
# TTTGTTGTCCAGTGCG.3.5                  0                0                0
# TTTGTTGTCGTGTGGC.22.6                 0                0                0
# TTTGTTGTCTCTTAAC.4.2                  0                0                0
#
# ensemble_gene_name      ENSG00000188976  ...  ENSG00000228253  \
# AAACCCAAGAGCCATG.10.13                0  ...                0
# AAACCCAAGCAGTACG.2.9                  0  ...                0
# AAACCCAAGCTGCCTG.9.14                 0  ...                0
# AAACCCAAGGCAGGGA.9.9                  0  ...                0
# AAACCCAAGGCATGGT.13.12                0  ...                0
# ...                                 ...  ...              ...
# TTTGTTGTCACGGTCG.8.6                  0  ...                0
# TTTGTTGTCAGAACCT.45.2                 0  ...                0
# TTTGTTGTCCAGTGCG.3.5                  1  ...                0
# TTTGTTGTCGTGTGGC.22.6                 0  ...                0
# TTTGTTGTCTCTTAAC.4.2                  0  ...                0
#
# ensemble_gene_name      ENSG00000198899  ENSG00000198938  ENSG00000198840  \
# AAACCCAAGAGCCATG.10.13                0                1                1
# AAACCCAAGCAGTACG.2.9                  0                0                1
# AAACCCAAGCTGCCTG.9.14                 0                1                0
# AAACCCAAGGCAGGGA.9.9                  1                2                2
# AAACCCAAGGCATGGT.13.12                2                1                0
# ...                                 ...              ...              ...
# TTTGTTGTCACGGTCG.8.6                  2                3                1
# TTTGTTGTCAGAACCT.45.2                27               15               25
# TTTGTTGTCCAGTGCG.3.5                  2                4                0
# TTTGTTGTCGTGTGGC.22.6                 0                0                0
# TTTGTTGTCTCTTAAC.4.2                  3                0                0
#
# ensemble_gene_name      ENSG00000212907  ENSG00000198886  ENSG00000198786  \
# AAACCCAAGAGCCATG.10.13                0                2                0
# AAACCCAAGCAGTACG.2.9                  0                0                0
# AAACCCAAGCTGCCTG.9.14                 0                1                0
# AAACCCAAGGCAGGGA.9.9                  0                0                0
# AAACCCAAGGCATGGT.13.12                0                0                0
# ...                                 ...              ...              ...
# TTTGTTGTCACGGTCG.8.6                  0                2                0
# TTTGTTGTCAGAACCT.45.2                 0               12                2
# TTTGTTGTCCAGTGCG.3.5                  0                0                0
# TTTGTTGTCGTGTGGC.22.6                 0                0                0
# TTTGTTGTCTCTTAAC.4.2                  0                0                0
#
# ensemble_gene_name      ENSG00000198695  ENSG00000198727  ENSG00000274847
# AAACCCAAGAGCCATG.10.13                0                1                0
# AAACCCAAGCAGTACG.2.9                  0                1                0
# AAACCCAAGCTGCCTG.9.14                 0                0                0
# AAACCCAAGGCAGGGA.9.9                  0                2                0
# AAACCCAAGGCATGGT.13.12                0                0                0
# ...                                 ...              ...              ...
# TTTGTTGTCACGGTCG.8.6                  0                2                0
# TTTGTTGTCAGAACCT.45.2                 0               16                0
# TTTGTTGTCCAGTGCG.3.5                  0                1                0
# TTTGTTGTCGTGTGGC.22.6                 0                0                0
# TTTGTTGTCTCTTAAC.4.2                  0                0                0
#
# [25877 rows x 22500 columns]

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Assuming merged_data_clinical_pathological is your data matrix (samples x features)
# and labels is a list/array of labels corresponding to each sample

# Standardize the data (important for PCA)
scaler = StandardScaler()
scaled_data = scaler.fit_transform(merged_data_clinical_pathological)

# Perform PCA
pca = PCA(n_components=10)  # Choose number of components
principal_components = pca.fit_transform(scaled_data)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.02963611, 0.00237102, 0.00179438, 0.0013373 , 0.00114981,
#        0.00101685, 0.00084531, 0.00075512, 0.0007068 , 0.00068896])

# %%
principal_components
# Out:
# array([[-26.43653167,  -0.43458564,   2.13520608, ...,  -1.89304083,
#           0.565888  ,  -0.14743508],
#        [ 10.27652516,  10.02163939,   0.82160085, ...,   3.71442129,
#          -0.3887953 ,  -0.38951664],
#        [-22.58088343,   1.050127  ,  -1.05196732, ...,   0.87331468,
#           0.72851392,  -0.23354038],
#        ...,
#        [ 19.70619431,   8.56438614,  -3.29491721, ...,   5.56598171,
#          -2.47219134,   5.04906057],
#        [-15.57795814,  -0.06622508,   2.36819987, ...,  -4.74126952,
#           0.70464496,   1.62651524],
#        [ 33.38722518, -10.54800127,  -8.05588582, ...,  -0.97587915,
#          -0.26762007,   2.4846466 ]])

# %%
correlation_matrix = np.corrcoef(principal_components.T, covariates_dataframe.T)[:principal_components.shape[1], principal_components.shape[1]:]

# %%
import seaborn as sns
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot Heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', xticklabels=covariates_dataframe.columns,
            yticklabels=[f'PC {i+1}' for i in range(principal_components.shape[1])], ax=ax1)
ax1.set_title('Correlation between PCs and Covariates')
# Out:
# Text(0.5, 1.0, 'Correlation between PCs and Covariates')

# %%
def shuffle_column(column):
    np.random.shuffle(column)
    return column

def permutation_test_covariates(df):
    shuffled_df = df.copy()
    return shuffled_df.reindex(np.random.permutation(shuffled_df.index))

# %%
shuffled_covariates = permutation_test_covariates(covariates_dataframe)

# %%
shuffled_covariates
# Out:
#                         age_death  msex  educ  cogdx  ceradsc  braaksc
# cell_id
# CTGATCCCAACTGATC.27.9   88.960986   1.0  20.0    4.0      1.0      4.0
# TACGCTCCACCCTTAC.6.13   83.304586   1.0  27.0    1.0      4.0      4.0
# TCGGGCAAGCCTGAAG.25.8   90.000000   0.0  12.0    1.0      4.0      4.0
# TGGATCATCGACGTCG.31.11  82.026010   1.0  19.0    4.0      1.0      5.0
# ATCGGCGGTGAGGAAA.26.2   89.308693   0.0  12.0    4.0      1.0      5.0
# ...                           ...   ...   ...    ...      ...      ...
# TAGAGTCGTCGAATGG.8.8    90.000000   0.0  12.0    4.0      1.0      6.0
# CATAAGCCACGATTCA.28.6   90.000000   0.0  12.0    1.0      4.0      3.0
# CTGAATGTCTACTCAT.11.12  90.000000   0.0  12.0    4.0      1.0      5.0
# TTTGTTGGTGCATGTT.10.14  86.168378   1.0  16.0    4.0      1.0      5.0
# AGTCTCCGTCCTACAA.8.11   87.868583   1.0  18.0    1.0      4.0      1.0
#
# [25877 rows x 6 columns]

# %%
principal_components.T.shape
# Out:
# (10, 25877)

# %%
covariates_clinical_data_AD_NCI = covariates_dataframe
X_pca_expression = principal_components

li = [[[] for i in range(covariates_clinical_data_AD_NCI.T.shape[0])] for l in range(X_pca_expression.shape[1])]
for l in range(X_pca_expression.shape[1]):
    x = np.array(np.array(X_pca_expression.T[l]))
    for i in range(1000):
        shuffled_covariates = permutation_test_covariates(covariates_clinical_data_AD_NCI)
        
        for k,j in enumerate(range(shuffled_covariates.T.shape[0])):
            y = np.array(np.array(shuffled_covariates.T.iloc[j,]))
            corr = np.corrcoef(x,y)[0,1]
            li[l][k].append(corr)

# %%
li.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 li.shape
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
li = np.array(li)
li = np.sort(np.abs(li), axis=1)
percentiles_90 = np.percentile(li, 90, axis=1)
percentiles_90
# Out:
# array([[0.00802568, 0.00693796, 0.00642946, ..., 0.01113155, 0.01154842,
#         0.01498778],
#        [0.00900295, 0.00978701, 0.01093003, ..., 0.01224911, 0.01199517,
#         0.00769879],
#        [0.00732681, 0.00757502, 0.00900958, ..., 0.00660561, 0.00648012,
#         0.00505433],
#        ...,
#        [0.00925531, 0.01115893, 0.01149895, ..., 0.00545674, 0.0089574 ,
#         0.01461899],
#        [0.00838265, 0.00707636, 0.00890855, ..., 0.00859444, 0.0119333 ,
#         0.00466548],
#        [0.00897757, 0.01228324, 0.00376009, ..., 0.00628991, 0.00815051,
#         0.00949922]])

# %%
li_pc_fdr = []
for i in li:   
    li_ = np.array(i)
    li_ = np.sort(np.abs(li_), axis=1)
    percentiles_90 = np.percentile(li_, 90, axis=1)
    li_pc_fdr.append(list(percentiles_90))

# %%
np.array(li_pc_fdr).shape
# Out:
# (10, 6)

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))
sns.heatmap(np.array(li_pc_fdr), annot=True, cmap='coolwarm', fmt='.2f', xticklabels=covariates_clinical_data_AD_NCI.columns, yticklabels=[f'PC {i+1}' for i in range(X_pca_expression.shape[1])], ax=ax1)
ax1.set_title('Correlation between PCs and Covariates')
# Out:
# Text(0.5, 1.0, 'Correlation between PCs and Covariates')

# %%
import seaborn as sns
fig, ax1 = plt.subplots(figsize=(12, 6))

# Plot Heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', xticklabels=covariates_dataframe.columns,
            yticklabels=[f'PC {i+1}' for i in range(principal_components.shape[1])], ax=ax1)
ax1.set_title('Correlation between PCs and Covariates')
# Out:
# Text(0.5, 1.0, 'Correlation between PCs and Covariates')
